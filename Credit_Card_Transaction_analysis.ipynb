# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pankaj-Str/Complete-Python-Mastery/refs/heads/main/53%20DataSet/credit_card_transactions.csv')

# %%
df.head()
# Out:
#    Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0          100000         4452       2023-01-01           Online  Walmart
# 1          100001         2775       2023-01-01              ATM  BestBuy
# 2          100002         2259       2023-01-01   Mobile Payment     Uber
# 3          100003         4545       2023-01-01           Online  BestBuy
# 4          100004         2137       2023-01-01              ATM   Amazon
#
#    Category   Amount Payment_Mode Transaction_Status       Location
# 0    Travel  4520.70   Debit Card           Approved      Jonesport
# 1    Travel  1437.85   Debit Card           Approved  Port Jennifer
# 2  Clothing  3320.52       PayPal           Approved     Port James
# 3    Travel  2659.96   Debit Card           Approved     Hawkinston
# 4    Travel  2517.07   Debit Card           Approved    Matthewland

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      5500 non-null   int64
#  1   Customer_ID         5500 non-null   int64
#  2   Transaction_Date    5500 non-null   object
#  3   Transaction_Type    5500 non-null   object
#  4   Merchant            5500 non-null   object
#  5   Category            5500 non-null   object
#  6   Amount              5500 non-null   float64
#  7   Payment_Mode        5500 non-null   object
#  8   Transaction_Status  5500 non-null   object
#  9   Location            5500 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 429.8+ KB

# %% [markdown]
# ### Data exploration and cleaning

# %%
df.head()
# Out:
#    Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0          100000         4452       2023-01-01           Online  Walmart
# 1          100001         2775       2023-01-01              ATM  BestBuy
# 2          100002         2259       2023-01-01   Mobile Payment     Uber
# 3          100003         4545       2023-01-01           Online  BestBuy
# 4          100004         2137       2023-01-01              ATM   Amazon
#
#    Category   Amount Payment_Mode Transaction_Status       Location
# 0    Travel  4520.70   Debit Card           Approved      Jonesport
# 1    Travel  1437.85   Debit Card           Approved  Port Jennifer
# 2  Clothing  3320.52       PayPal           Approved     Port James
# 3    Travel  2659.96   Debit Card           Approved     Hawkinston
# 4    Travel  2517.07   Debit Card           Approved    Matthewland

# %%
print('df shape:', df.shape)
print('df size:', df.size)
print('\ndf dtypes:\n', df.dtypes)
# Out:
# df shape: (5500, 10)
# df size: 55000
#
# df dtypes:
#  Transaction_ID          int64
# Customer_ID             int64
# Transaction_Date       object
# Transaction_Type       object
# Merchant               object
# Category               object
# Amount                float64
# Payment_Mode           object
# Transaction_Status     object
# Location               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction_ID        0
# Customer_ID           0
# Transaction_Date      0
# Transaction_Type      0
# Merchant              0
# Category              0
# Amount                0
# Payment_Mode          0
# Transaction_Status    0
# Location              0
# dtype: int64

# %% [markdown]
# Hence no null found moving to next step

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      5500 non-null   int64
#  1   Customer_ID         5500 non-null   int64
#  2   Transaction_Date    5500 non-null   datetime64[ns]
#  3   Transaction_Type    5500 non-null   object
#  4   Merchant            5500 non-null   object
#  5   Category            5500 non-null   object
#  6   Amount              5500 non-null   float64
#  7   Payment_Mode        5500 non-null   object
#  8   Transaction_Status  5500 non-null   object
#  9   Location            5500 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 429.8+ KB

# %%
df['Transaction_year'] = df['Transaction_Date'].dt.year
df['Transaction_month'] = df['Transaction_Date'].dt.month
df['Transaction_day'] = df['Transaction_Date'].dt.day
df.sample(5, random_state=42)
# Out:
#       Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 4747          104747         4293       2023-07-17              ATM  Walmart
# 1199          101199         3477       2023-02-19   Mobile Payment   Amazon
# 5222          105222         1952       2023-08-06           Online  BestBuy
# 4547          104547         3230       2023-07-09              POS  BestBuy
# 1862          101862         2065       2023-03-19   Mobile Payment  BestBuy
#
#            Category   Amount Payment_Mode Transaction_Status        Location  \
# 4747  Entertainment   428.92   Debit Card           Approved      Connieport
# 1199  Entertainment   582.34   Debit Card           Approved       Olsonview
# 5222      Groceries  4228.18       PayPal           Approved      West Amber
# 4547         Travel   452.03  Credit Card           Declined        Richland
# 1862    Electronics  3263.94          UPI           Approved  South Jennifer
#
# ...

# %% [markdown]
# ### Data selection and Indexing

# %%
result = df.loc[(df['Transaction_month'] == 1) & (df['Transaction_year'] == 2024)]
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Customer_ID, Transaction_Date, Transaction_Type, Merchant, Category, Amount, Payment_Mode, Transaction_Status, Location, Transaction_year, Transaction_month, Transaction_day]
# Index: []

# %%
df['Transaction_year'].unique()
# Out:
# array([2023], dtype=int32)

# %%
df['Transaction_month'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int32)

# %% [markdown]
# As the data only contain records of year -> 2024.

# %%
result = df.loc[(df['Transaction_month'] == 1) & (df['Transaction_year'] == 2023)]
result
# Out:
#      Transaction_ID  Customer_ID Transaction_Date Transaction_Type  \
# 0            100000         4452       2023-01-01           Online
# 1            100001         2775       2023-01-01              ATM
# 2            100002         2259       2023-01-01   Mobile Payment
# 3            100003         4545       2023-01-01           Online
# 4            100004         2137       2023-01-01              ATM
# ..              ...          ...              ...              ...
# 739          100739         3898       2023-01-31              POS
# 740          100740         2457       2023-01-31   Mobile Payment
# 741          100741         2107       2023-01-31   Mobile Payment
# 742          100742         2678       2023-01-31              POS
# 743          100743         4586       2023-01-31              ATM
#
#         Merchant     Category   Amount Payment_Mode Transaction_Status  \
# 0        Walmart       Travel  4520.70   Debit Card           Approved
# ...

# %%
print(df['Transaction_Type'].unique())
# Out:
# ['Online' 'ATM' 'Mobile Payment' 'POS']

# %%
df[(df['Transaction_Type'] == 'Online') & (df['Amount'] > 1000)]
# Out:
#       Transaction_ID  Customer_ID Transaction_Date Transaction_Type  \
# 0             100000         4452       2023-01-01           Online
# 3             100003         4545       2023-01-01           Online
# 6             100006         1587       2023-01-01           Online
# 14            100014         1855       2023-01-01           Online
# 18            100018         4438       2023-01-01           Online
# ...              ...          ...              ...              ...
# 5469          105469         4262       2023-08-16           Online
# 5474          105474         4692       2023-08-17           Online
# 5486          105486         1608       2023-08-17           Online
# 5487          105487         4593       2023-08-17           Online
# 5497          105497         3978       2023-08-18           Online
#
#          Merchant       Category   Amount Payment_Mode Transaction_Status  \
# 0         Walmart         Travel  4520.70   Debit Card           Approved
# ...
